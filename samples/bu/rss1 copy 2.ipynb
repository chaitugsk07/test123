# %%
import requests
import requests
import feedparser
from datetime import datetime, timezone
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
import pyperclip
import time
import cv2
import numpy as np
import requests
import json
from io import BytesIO
from skimage.feature import match_template
from skimage.color import rgb2gray
from transformers import pipeline
import os
import torch
from InstructorEmbedding import INSTRUCTOR
import numpy
# Enable device-side assertions
torch.backends.cuda.matmul.allow_tf32 = False
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.backends.cuda.use_deterministic_algorithms = True
torch.backends.cuda.cufft_plan_cache.clear()
torch.backends.cudnn.cache_enabled = False
torch.backends.cudnn.allow_tf32 = False
torch.backends.cudnn.enabled = True
torch.backends.cuda.deterministic = True
torch.backends.cuda.flags = {
    'assert': str(int(True)),
    'allow_tf32': str(int(False)),
    'cudnn_deterministic': str(int(True)),
    'cudnn_benchmark': str(int(False)),
    'use_deterministic_algorithms': str(int(True)),
    'cufft_plan_cache_clear': str(int(True)),
    'cudnn_cache_enabled': str(int(False)),
    'cudnn_allow_tf32': str(int(False)),
    'cudnn_enabled': str(int(True)),
    'cudnn_deterministic': str(int(True)),
}
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

endpoint = "http://hasura.192.168.0.100.nip.io/v1/graphql"
admin_key = "arrive@AD123"

def query_hasura_graphql(endpoint, admin_key, query, variables):
    headers = {
        'Content-Type': 'application/json',
        'x-hasura-admin-secret': f'{admin_key}'
    }

    data = {
        'query': query,
        'variables': variables
    }
    response = requests.post(endpoint, json=data, headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Request failed with status code {response.status_code}")
        return None

def is_valid_timezone_format(published):
    try:
        # Attempt to parse the string
        date_format = "%a, %d %b %Y %H:%M:%S %z"
        date_object = datetime.strptime(published, date_format)
        
        hasura_timestamp = date_object.astimezone(timezone.utc).isoformat()
        return True, hasura_timestamp
    except ValueError:
        # If parsing fails, the string is not in the correct format
        return False, None

def check_date_format(date_string):
    try:
        datetime.strptime(date_string, '%Y-%m-%dT%H:%M:%S%z')
        return True
    except ValueError:
        return False
        
def mutation_hasura_graphql(endpoint, admin_key, mutation_query, mutation_variables):
    headers = {
        'Content-Type': 'application/json',
        'x-hasura-admin-secret': f'{admin_key}'
    }
    response = requests.post(endpoint, json={'query': mutation_query, 'variables': mutation_variables}, headers=headers)
    if response.ok:
        data = response.json()
        print(data)
        return True, data
    else:
        print(f"Mutation failed with status code {response.status_code}: {response.text}")
        return False, None

def update_articles_toi():
    graphql_query = '''
    query MyQuery($outlet: String!, $link_type: Int!) {
    rss1_links(where: {rss1_link_type: {_eq: $link_type}, outlet: {_eq: $outlet}}) {
        rss1_link
    }
    }
    '''
    # Define the variables dictionary
    variables = {
        "link_type": 11,
        "outlet": "timesofindia"
    }
    rss1_links_array = []
    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    if response_data:
        rss1_links_array = [item["rss1_link"] for item in response_data["data"]["rss1_links"]]
    #print(rss1_links_array)
    graphql_query = """
    query MyQuery($outlet: String!) {
        rss1_outlets(where: {outlet: {_eq: $outlet}}) {
            logo_url
        }
    }
    """
    # Define the variables dictionary
    variables = {
        "outlet": "timesofindia"
    }
    mutation_query = """
    mutation MyMutation($objects: [rss1_articals_insert_input!] = {}) {
    insert_rss1_articals(objects: $objects, on_conflict: {constraint: rss1_articals_post_link_key}) {
        returning {
        id
        }
    }
    }
    """

    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    for feed_link in rss1_links_array:
        NewsFeed = feedparser.parse(feed_link)
        is_default_image = 0
        logo_url = response_data['data']['rss1_outlets'][0]['logo_url']
        print("############################################################")
        print(feed_link)
        articles = []
        for entry in NewsFeed.entries:
            # print(entry.link)
            is_default_image = 0
            title = entry.title
            summary_nofil = entry.summary
            summary = re.sub('<[^<]+?>', '', summary_nofil)
            image_url = logo_url
            for link in entry.links:
                if link.type == "image/jpeg":
                    image_url= link.href
                    is_default_image = 1
                    break
            post_link = entry.link
            published = entry.published
            datevalidation = is_valid_timezone_format(published)
            if datevalidation[0]:
                hasura_timestamp = datevalidation[1]
            if check_date_format(published):
                hasura_timestamp = published
            else:
                hasura_timestamp = datetime.now().astimezone(timezone.utc).isoformat()
            if "author" in entry:
                author = entry.author
            else:
                author = "na"
            articles.append({
                    "rss1_link": feed_link,
                    "post_link": post_link,
                    "title": title,
                    "summary": summary,
                    "author": author,
                    "image_link" : image_url,
                    "post_published": hasura_timestamp,
                    "is_default_image": is_default_image,
                }
            )
            #print(feed_link, post_link, title, summary, author, image_url, hasura_timestamp, is_default_image)
        mutation_variables = {
            "objects": articles
        }
        #print({'query': mutation_query, 'variables': mutation_variables})
        out1 = mutation_hasura_graphql(endpoint = endpoint, admin_key = admin_key, mutation_query = mutation_query, mutation_variables = mutation_variables)

def update_articles_thehindu():
    graphql_query = '''
    query MyQuery($outlet: String!, $link_type: Int!) {
    rss1_links(where: {rss1_link_type: {_eq: $link_type}, outlet: {_eq: $outlet}}) {
        rss1_link
    }
    }
    '''
    # Define the variables dictionary
    variables = {
        "link_type": 11,
        "outlet": "thehindu"
    }
    rss1_links_array = []
    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    if response_data:
        rss1_links_array = [item["rss1_link"] for item in response_data["data"]["rss1_links"]]
    #print(rss1_links_array)
    graphql_query = """
    query MyQuery($outlet: String!) {
        rss1_outlets(where: {outlet: {_eq: $outlet}}) {
            logo_url
        }
    }
    """
    # Define the variables dictionary
    variables = {
        "outlet": "thehindu"
    }
    mutation_query = """
    mutation MyMutation($objects: [rss1_articals_insert_input!] = {}) {
    insert_rss1_articals(objects: $objects, on_conflict: {constraint: rss1_articals_post_link_key}) {
        returning {
        id
        }
    }
    }
    """

    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    for feed_link in rss1_links_array:
        NewsFeed = feedparser.parse(feed_link)
        is_default_image = 0
        logo_url = response_data['data']['rss1_outlets'][0]['logo_url']
        print("############################################################")
        print(feed_link)
        articles = []
        for entry in NewsFeed.entries:
            # print(entry.link)
            is_default_image = 0
            title = entry.title
            summary_nofil = entry.summary
            summary = re.sub('<[^<]+?>', '', summary_nofil)
            image_url = logo_url
            for link in entry.links:
                if link.type == "image/jpeg":
                    image_url= link.href
                    is_default_image = 1
                    break
            post_link = entry.link
            published = entry.published
            datevalidation = is_valid_timezone_format(published)
            if datevalidation[0]:
                hasura_timestamp = datevalidation[1]
            if check_date_format(published):
                hasura_timestamp = published
            else:
                hasura_timestamp = datetime.now().astimezone(timezone.utc).isoformat()
            if "author" in entry:
                author = entry.author
            else:
                author = "na"
            articles.append({
                    "rss1_link": feed_link,
                    "post_link": post_link,
                    "title": title,
                    "summary": summary,
                    "author": author,
                    "image_link" : image_url,
                    "post_published": hasura_timestamp,
                    "is_default_image": is_default_image,
                }
            )
            #print(feed_link, post_link, title, summary, author, image_url, hasura_timestamp, is_default_image)
        mutation_variables = {
            "objects": articles
        }
        #print({'query': mutation_query, 'variables': mutation_variables})
        out1 = mutation_hasura_graphql(endpoint = endpoint, admin_key = admin_key, mutation_query = mutation_query, mutation_variables = mutation_variables)

def update_articles_cnn():
    graphql_query = '''
    query MyQuery($outlet: String!, $link_type: Int!) {
    rss1_links(where: {rss1_link_type: {_eq: $link_type}, outlet: {_eq: $outlet}}) {
        rss1_link
    }
    }
    '''
    # Define the variables dictionary
    variables = {
        "link_type": 11,
        "outlet": "cnn"
    }
    rss1_links_array = []
    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    if response_data:
        rss1_links_array = [item["rss1_link"] for item in response_data["data"]["rss1_links"]]
    #print(rss1_links_array)
    graphql_query = """
    query MyQuery($outlet: String!) {
        rss1_outlets(where: {outlet: {_eq: $outlet}}) {
            logo_url
        }
    }
    """
    # Define the variables dictionary
    variables = {
        "outlet": "cnn"
    }
    mutation_query = """
    mutation MyMutation($objects: [rss1_articals_insert_input!] = {}) {
    insert_rss1_articals(objects: $objects, on_conflict: {constraint: rss1_articals_post_link_key}) {
        returning {
        id
        }
    }
    }
    """

    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    for feed_link in rss1_links_array:
        NewsFeed = feedparser.parse(feed_link)
        is_default_image = 0
        logo_url = response_data['data']['rss1_outlets'][0]['logo_url']
        print("############################################################")
        print(feed_link)
        articles = []
        for entry in NewsFeed.entries:
            # print(entry.link)
            is_default_image = 0
            title = entry.title
            summary = ''
            if 'summary' in entry:
                summary_nofil = entry.summary
                summary = re.sub('<[^<]+?>', '', summary_nofil)
            image_url = logo_url
            if 'media_content' in entry:
                image_url = entry['media_content'][0]['url']
                is_default_image = 1
            for link in entry.links:
                if link.type == "image/jpeg":
                    image_url= link.href
                    is_default_image = 1
                    break
            post_link = entry.link
            published = datetime.now(timezone.utc).isoformat()
            if 'published' in entry:
                published = entry.published
            datevalidation = is_valid_timezone_format(published)
            if datevalidation[0]:
                hasura_timestamp = datevalidation[1]
            if check_date_format(published):
                hasura_timestamp = published
            else:
                hasura_timestamp = datetime.now().astimezone(timezone.utc).isoformat()
            if "author" in entry:
                author = entry.author
            else:
                author = "na"
            articles.append({
                    "rss1_link": feed_link,
                    "post_link": post_link,
                    "title": title,
                    "summary": summary,
                    "author": author,
                    "image_link" : image_url,
                    "post_published": hasura_timestamp,
                    "is_default_image": is_default_image,
                }
            )
            #print(feed_link, post_link, title, summary, author, image_url, hasura_timestamp, is_default_image)
        mutation_variables = {
            "objects": articles
        }
        #print({'query': mutation_query, 'variables': mutation_variables})
        out1 = mutation_hasura_graphql(endpoint = endpoint, admin_key = admin_key, mutation_query = mutation_query, mutation_variables = mutation_variables)

def update_articles_foxnews():
    graphql_query = '''
    query MyQuery($outlet: String!, $link_type: Int!) {
    rss1_links(where: {rss1_link_type: {_eq: $link_type}, outlet: {_eq: $outlet}}) {
        rss1_link
    }
    }
    '''
    # Define the variables dictionary
    variables = {
        "link_type": 11,
        "outlet": "foxnews"
    }
    rss1_links_array = []
    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    if response_data:
        rss1_links_array = [item["rss1_link"] for item in response_data["data"]["rss1_links"]]
    #print(rss1_links_array)
    graphql_query = """
    query MyQuery($outlet: String!) {
        rss1_outlets(where: {outlet: {_eq: $outlet}}) {
            logo_url
        }
    }
    """
    # Define the variables dictionary
    variables = {
        "outlet": "foxnews"
    }
    mutation_query = """
    mutation MyMutation($objects: [rss1_articals_insert_input!] = {}) {
    insert_rss1_articals(objects: $objects, on_conflict: {constraint: rss1_articals_post_link_key}) {
        returning {
        id
        }
    }
    }
    """

    response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
    for feed_link in rss1_links_array:
        NewsFeed = feedparser.parse(feed_link)
        is_default_image = 0
        logo_url = response_data['data']['rss1_outlets'][0]['logo_url']
        print("############################################################")
        print(feed_link)
        articles = []
        for entry in NewsFeed.entries:
            # print(entry.link)
            is_default_image = 0
            title = entry.title
            summary = ''
            if 'summary' in entry:
                summary_nofil = entry.summary
                summary = re.sub('<[^<]+?>', '', summary_nofil)
            image_url = logo_url
            if 'media_content' in entry:
                image_url = entry['media_content'][0]['url']
                is_default_image = 1
            if 'links' in entry:
                for link in entry.links:
                    if link.type == "image/jpeg":
                        image_url= link.href
                        is_default_image = 1
                        break
            post_link = entry.link
            published = datetime.now(timezone.utc).isoformat()
            if 'published' in entry:
                published = entry.published
            datevalidation = is_valid_timezone_format(published)
            if datevalidation[0]:
                hasura_timestamp = datevalidation[1]
            if check_date_format(published):
                hasura_timestamp = published
            else:
                hasura_timestamp = datetime.now().astimezone(timezone.utc).isoformat()
            if "author" in entry:
                author = entry.author
            else:
                author = "na"
            articles.append({
                    "rss1_link": feed_link,
                    "post_link": post_link,
                    "title": title,
                    "summary": summary,
                    "author": author,
                    "image_link" : image_url,
                    "post_published": hasura_timestamp,
                    "is_default_image": is_default_image,
                }
            )
            #print(feed_link, post_link, title, summary, author, image_url, hasura_timestamp, is_default_image)
        mutation_variables = {
            "objects": articles
        }
        #print({'query': mutation_query, 'variables': mutation_variables})
        out1 = mutation_hasura_graphql(endpoint = endpoint, admin_key = admin_key, mutation_query = mutation_query, mutation_variables = mutation_variables)

def load_image_from_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        return cv2.imdecode(np.frombuffer(response.content, np.uint8), -1)
    else:
        return None

def update_article_detail_toi_with_images():
    graphql_query = '''
    query MyQuery($limit: Int!, $offset: Int!) {
        rss1_articals(offset: $offset, limit: $limit, where: {is_in_detail: {_eq: 0}, rss1LinkByRss1Link: {outlet: {_eq: "timesofindia"}}}, order_by: {post_published: desc}) {
            post_link
            is_default_image
            image_link
            id
        }
        }
    '''
    offset = 0
    mutation_query = """
    mutation MyMutation($objects: [rss1_articles_detail_insert_input!] = {}, $updates: [rss1_articals_updates!] = {where: {}}) {
    insert_rss1_articles_detail(objects: $objects, on_conflict: {constraint: rss1_articles_detail_post_link_key}) {
        affected_rows
        returning {
        id
        }
    }
    update_rss1_articals_many(updates: $updates) {
        affected_rows
        returning {
        id
        }
    }
    }
    """    
    options = webdriver.EdgeOptions()
    options.use_chromium = True
    options.add_argument('--enable-immersive-reader')
    driver = webdriver.Edge(options=options)
    while True:
        variables = {
        "limit": 2,
        "offset": offset
        }
        response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
        #print(variables, response_data)
        #print(response_data)
        post_links_array = []
        ids=[]
        if response_data:
            post_links_array = [item["post_link"] for item in response_data["data"]["rss1_articals"]]
            is_default_image_array = [item["is_default_image"] for item in response_data["data"]["rss1_articals"]]
            image_link_array = [item["image_link"] for item in response_data["data"]["rss1_articals"]]
            ids=[item["id"] for item in response_data["data"]["rss1_articals"]]
        articles_detail = []
        articles_update = []
        if len(post_links_array) == 0:
            break
        try:
            for a in range(len(post_links_array)):
                main_link = post_links_array[a]
                print(main_link)
                read_link= "read://"+main_link
                driver.get(read_link)
                time.sleep(5)
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('a').key_up(Keys.CONTROL).perform()
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('c').key_up(Keys.CONTROL).perform()
                text = pyperclip.paste()
                text2 = text
                text3 = text2.split('\n')
                text3 = [s.replace('\r', '') for s in text3]
                special_chars = set("!@#$%^&*()_+[]{}|;:'\",<>?")
                text4 = [s for s in text3 if len(s) > 0 and (s[0] not in special_chars or s[-1] not in special_chars)]
                my_list = text4
                my_set = set()
                desription = []
                for item in my_list:
                    if item not in my_set:
                        desription.append(item)
                        my_set.add(item)
                #print(desription)
                driver.get(main_link)
                time.sleep(5)
                try: 
                    xpath = f"""//*/img[@alt="{desription[0]}"]"""
                    elements = driver.find_elements(By.XPATH, xpath)
                    #print(elements)
                    images = [element.get_attribute("src") for element in elements]
                    #print(images)
                except:
                    images = []
                if is_default_image_array[a] == 1:
                    images_1 = [image_link_array[a]] + images
                else:
                    images_1 = images
                images_final = list(set(images_1))
                images_to_remove = []
                if len(images_final) > 1:
                    image_urls = images_final
                    for i in range(len(image_urls)):
                        for j in range(i+1, len(image_urls)):
                            image1 = load_image_from_url(image_urls[i])
                            image2 = load_image_from_url(image_urls[j])

                            if image1 is None or image2 is None:
                                print(f"Failed to load one or both images for comparison between image {i+1} and image {j+1}.")
                                continue

                            # Resize the images to the same dimensions for comparison
                            height, width, _ = image1.shape
                            image3 = cv2.resize(image2, (width, height))

                            # Convert the images to grayscale
                            gray_image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
                            gray_image2 = cv2.cvtColor(image3, cv2.COLOR_BGR2GRAY)

                            # Calculate the structural similarity
                            result = match_template(gray_image1, gray_image2)
                            ssim = np.max(result)

                            # Display the SSIM value (a higher value indicates more similarity)
                            #print(f"SSIM between image {i+1} and image {j+1}: {ssim}")
                            height1, width1, _ = image1.shape
                            height2, width2, _ = image2.shape
                            height1, width1, _ = image1.shape
                            height2, width2, _ = image2.shape
                            if height1 * width1 >= height2 * width2 and ssim > 0.8:
                                images_to_remove.append(image_urls[i+1])
                            elif height1 * width1 < height2 * width2 and ssim > 0.8:
                                images_to_remove.append(image_urls[i])

                    # Remove the images that were marked for removal
                    for image_url in images_to_remove:
                        if image_url in images_final:
                            images_final.remove(image_url)
                #print(images_final)
                articles_detail.append({
                    "article_id": ids[a],
                    "title": desription[0],
                    "discription": desription[1:],
                    "image_link": images_final,
                }
                )
                if (is_default_image_array[a] == 0 and len(images_final) > 0):
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1 , "image_link": images_final[0], "is_default_image": 1}
                    })
                else:
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1}
                    })
                
                #print(main_link, desription[0], desription[1:], images_final)
            #print(articles_update)
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        except:
            offset = offset + 1
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        
    driver.quit() 

def update_article_detail_toi():
    graphql_query = '''
    query MyQuery($limit: Int!, $offset: Int!) {
        rss1_articals(offset: $offset, limit: $limit, where: {is_in_detail: {_eq: 0}, rss1LinkByRss1Link: {outlet: {_eq: "timesofindia"}}}, order_by: {post_published: desc}) {
            post_link
            is_default_image
            image_link
            id
        }
        }
    '''
    offset = 0
    mutation_query = """
    mutation MyMutation($objects: [rss1_articles_detail_insert_input!] = {}, $updates: [rss1_articals_updates!] = {where: {}}) {
    insert_rss1_articles_detail(objects: $objects, on_conflict: {constraint: rss1_articles_detail_article_id_key}) {
        affected_rows
        returning {
        id
        }
    }
    update_rss1_articals_many(updates: $updates) {
        affected_rows
        returning {
        id
        }
    }
    }
    """    
    options = webdriver.EdgeOptions()
    options.use_chromium = True
    options.add_argument('--enable-immersive-reader')
    driver = webdriver.Edge(options=options)
    while True:
        variables = {
        "limit": 20,
        "offset": offset
        }
        response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
        #print(variables, response_data)
        #print(response_data)
        post_links_array = []
        ids=[]
        if response_data:
            post_links_array = [item["post_link"] for item in response_data["data"]["rss1_articals"]]
            is_default_image_array = [item["is_default_image"] for item in response_data["data"]["rss1_articals"]]
            image_link_array = [item["image_link"] for item in response_data["data"]["rss1_articals"]]
            ids=[item["id"] for item in response_data["data"]["rss1_articals"]]
        articles_detail = []
        articles_update = []
        if len(post_links_array) == 0:
            break
        try:
            for a in range(len(post_links_array)):
                main_link = post_links_array[a]
                print(main_link)
                read_link= "read://"+main_link
                driver.get(read_link)
                time.sleep(5)
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('a').key_up(Keys.CONTROL).perform()
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('c').key_up(Keys.CONTROL).perform()
                text = pyperclip.paste()
                text2 = text
                text3 = text2.split('\n')
                text3 = [s.replace('\r', '') for s in text3]
                special_chars = set("!@#$%^&*()_+[]{}|;:'\",<>?")
                text4 = [s for s in text3 if len(s) > 0 and (s[0] not in special_chars or s[-1] not in special_chars)]
                my_list = text4
                my_set = set()
                desription = []
                for item in my_list:
                    if item not in my_set:
                        desription.append(item)
                        my_set.add(item)
                #print(desription)
                images_final = []
                articles_detail.append({
                    "article_id": ids[a],
                    "title": desription[0],
                    "description": desription[1:],
                    "image_link": images_final,
                }
                )
                if (is_default_image_array[a] == 0 and len(images_final) > 0):
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1 , "image_link": images_final[0], "is_default_image": 1}
                    })
                else:
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1}
                    })
                
                #print(main_link, desription[0], desription[1:], images_final)
            #print(articles_update)
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        except:
            offset = offset + 1
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        
    driver.quit() 

def update_article_detail_cnn(offset1):
    graphql_query = '''
    query MyQuery($limit: Int!, $offset: Int!) {
        rss1_articals(offset: $offset, limit: $limit, where: {is_in_detail: {_eq: 0}, rss1LinkByRss1Link: {outlet: {_eq: "cnn"}}}, order_by: {post_published: desc}) {
            post_link
            is_default_image
            image_link
            id
        }
        }
    '''
    offset = offset1
    mutation_query = """
    mutation MyMutation($objects: [rss1_articles_detail_insert_input!] = {}, $updates: [rss1_articals_updates!] = {where: {}}) {
    insert_rss1_articles_detail(objects: $objects, on_conflict: {constraint: rss1_articles_detail_article_id_key}) {
        affected_rows
        returning {
        id
        }
    }
    update_rss1_articals_many(updates: $updates) {
        affected_rows
        returning {
        id
        }
    }
    }
    """    
    options = webdriver.EdgeOptions()
    options.use_chromium = True
    options.add_argument('--enable-immersive-reader')
    driver = webdriver.Edge(options=options)
    while True:
        variables = {
        "limit": 2,
        "offset": offset
        }
        response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
        #print(variables, response_data)
        #print(response_data)
        post_links_array = []
        ids=[]
        if response_data:
            post_links_array = [item["post_link"] for item in response_data["data"]["rss1_articals"]]
            is_default_image_array = [item["is_default_image"] for item in response_data["data"]["rss1_articals"]]
            image_link_array = [item["image_link"] for item in response_data["data"]["rss1_articals"]]
            ids=[item["id"] for item in response_data["data"]["rss1_articals"]]
        articles_detail = []
        articles_update = []
        if len(post_links_array) == 0:
            break
        try:
            for a in range(len(post_links_array)):
                main_link = post_links_array[a]
                print(main_link)
                driver.get(main_link)
                get_url = driver.current_url
                read_link= "read://"+get_url
                driver.get(read_link)
                time.sleep(5)
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('a').key_up(Keys.CONTROL).perform()
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('c').key_up(Keys.CONTROL).perform()
                text = pyperclip.paste()
                text2 = text
                text3 = text2.split('\n')
                text3 = [s.replace('\r', '') for s in text3]
                special_chars = set("!@#$%^&*()_+[]{}|;:'\",<>?")
                text4 = [s for s in text3 if len(s) > 0 and (s[0] not in special_chars or s[-1] not in special_chars)]
                my_list = text4
                my_set = set()
                desription = []
                for item in my_list:
                    if item not in my_set:
                        desription.append(item)
                        my_set.add(item)
                #print(desription)
                images_final = []
                articles_detail.append({
                    "article_id": ids[a],
                    "title": desription[0],
                    "description": desription[1:],
                    "image_link": images_final,
                }
                )
                if (is_default_image_array[a] == 0 and len(images_final) > 0):
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1 , "image_link": images_final[0], "is_default_image": 1}
                    })
                else:
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1}
                    })
                
                #print(main_link, desription[0], desription[1:], images_final)
            #print(articles_update)
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        except:
            offset = offset + 1
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        
    driver.quit() 

def update_article_detail_foxnews(offset1):
    graphql_query = '''
    query MyQuery($limit: Int!, $offset: Int!) {
        rss1_articals(offset: $offset, limit: $limit, where: {is_in_detail: {_eq: 0}, rss1LinkByRss1Link: {outlet: {_eq: "thehindu"}}}, order_by: {post_published: desc}) {
            post_link
            is_default_image
            image_link
            id
        }
        }
    '''
    offset = offset1
    mutation_query = """
    mutation MyMutation($objects: [rss1_articles_detail_insert_input!] = {}, $updates: [rss1_articals_updates!] = {where: {}}) {
    insert_rss1_articles_detail(objects: $objects, on_conflict: {constraint: rss1_articles_detail_article_id_key}) {
        affected_rows
        returning {
        id
        }
    }
    update_rss1_articals_many(updates: $updates) {
        affected_rows
        returning {
        id
        }
    }
    }
    """    
    options = webdriver.EdgeOptions()
    options.use_chromium = True
    options.add_argument('--enable-immersive-reader')
    driver = webdriver.Edge(options=options)
    while True:
        variables = {
        "limit": 2,
        "offset": offset
        }
        response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
        #print(variables, response_data)
        #print(response_data)
        post_links_array = []
        ids=[]
        if response_data:
            post_links_array = [item["post_link"] for item in response_data["data"]["rss1_articals"]]
            is_default_image_array = [item["is_default_image"] for item in response_data["data"]["rss1_articals"]]
            image_link_array = [item["image_link"] for item in response_data["data"]["rss1_articals"]]
            ids=[item["id"] for item in response_data["data"]["rss1_articals"]]
        articles_detail = []
        articles_update = []
        if len(post_links_array) == 0:
            break
        try:
            for a in range(len(post_links_array)):
                main_link = post_links_array[a]
                print(main_link)
                driver.get(main_link)
                get_url = driver.current_url
                read_link= "read://"+get_url
                driver.get(read_link)
                time.sleep(5)
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('a').key_up(Keys.CONTROL).perform()
                ActionChains(driver).key_down(Keys.CONTROL).send_keys('c').key_up(Keys.CONTROL).perform()
                text = pyperclip.paste()
                text2 = text
                text3 = text2.split('\n')
                text3 = [s.replace('\r', '') for s in text3]
                special_chars = set("!@#$%^&*()_+[]{}|;:'\",<>?")
                text4 = [s for s in text3 if len(s) > 0 and (s[0] not in special_chars or s[-1] not in special_chars)]
                my_list = text4
                my_set = set()
                desription = []
                for item in my_list:
                    if item not in my_set:
                        desription.append(item)
                        my_set.add(item)
                #print(desription)
                images_final = []
                articles_detail.append({
                    "article_id": ids[a],
                    "title": desription[0],
                    "description": desription[1:],
                    "image_link": images_final,
                }
                )
                if (is_default_image_array[a] == 0 and len(images_final) > 0):
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1 , "image_link": images_final[0], "is_default_image": 1}
                    })
                else:
                    articles_update.append({
                        "where": {"post_link" : { "_eq": main_link }},
                        "_set": {"is_in_detail": 1}
                    })
                
                #print(main_link, desription[0], desription[1:], images_final)
            #print(articles_update)
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        except:
            offset = offset + 1
            mutation_variables = {
            "objects": articles_detail,
            "updates": articles_update,
            }
            out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)
        
    driver.quit() 

def summerizer(offset1): 
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn", device=0)
    graphql_query = '''
    query MyQuery($limit: Int!, $offset: Int!) {
    rss1_articles_detail(limit: $limit, offset: $offset, where: {summary: {_is_null: true}}) {
        title
        description
        rss1_artical {
        title
        summary
        }
        article_id
    }
    }
    '''
    offset = offset1
    mutation_query = """
    mutation MyMutation($updates: [rss1_articles_detail_updates!] = {where: {}}) {
        update_rss1_articles_detail_many(updates: $updates) {
            affected_rows
            returning {
            id
            }
        }
        }
    """
    while True:
        variables = {
        "limit": 2,
        "offset": offset
        }
        rss1_articles_detail_updates = []
        response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
        if len(response_data['data']['rss1_articles_detail']) == 0:
            break
        for response in response_data['data']['rss1_articles_detail']:
            print(response['title'])
            article=""
            article = article + response['title'] + " " +  response['rss1_artical']['title'] + " " +  response['rss1_artical']['summary'] + ', '.join(response['description'])
            chunks=[]
            max_length = 0
            min_length = 0
            if len(article) < 1000:
                max_length = 150
                min_length = 100
                chunks.append(article)
            elif len(article) < 3000:
                max_length = 300
                min_length = 200
                chunks.append(article)
            elif len(article) < 4000:
                max_length = 400
                min_length = 250
                chunks.append(article)
            elif len(article) < 8000:
                max_length = 200
                min_length = 150
                midpoint = len(article) // 2
                chunks.append(article[:midpoint])
                chunks.append(article[midpoint:])
            else:
                article=article[:8000]
                max_length = 200
                min_length = 150
                midpoint = len(article) // 2
                chunks.append(article[:midpoint])
                chunks.append(article[midpoint:])

            summerize=""
            for chunk in chunks:
                summerize=summerize + summarizer(chunk, max_length=max_length, min_length=min_length, do_sample=False)[0]['summary_text']+ " "
            if len(summerize) > 0:
                rss1_articles_detail_updates.append({
                    "where": {"article_id" : { "_eq": response['article_id'] }},
                    "_set": {"summary": summerize }
                })
        mutation_variables = {
            "updates": rss1_articles_detail_updates,
            }
        out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)

def vectorize(offset1):
    model = INSTRUCTOR('hkunlp/instructor-xl', device=0)
    graphql_query = '''
    query MyQuery($limit: Int!, $offset: Int!) {
    rss1_articals(limit: $limit, offset: $offset, where: {is_vectorized: {_eq: 0}, is_in_detail: {_eq: 1}}) {
        id
        title
        summary
        rss1_articles_details {
        summary
        tags
        }
    }
    }
    '''
    offset = offset1
    mutation_query = """
    mutation MyMutation($objects: [articles_vector1_insert_input!] = {}, $updates: [rss1_articals_updates!] = {where: {}}) {
    insert_articles_vector1(objects: $objects, on_conflict: {constraint: articles_vector1_article_id_key}) {
        affected_rows
        returning {
        article_id
        }
    }
    update_rss1_articals_many(updates: $updates) {
        affected_rows
        returning {
        id
        }
    }
    }

    """
    while True:
        variables = {
        "limit": 1,
        "offset": offset
        }
        articles_vector1_insert_input_loc=[]
        rss1_articals_updates_loc=[]
        response_data = query_hasura_graphql(endpoint, admin_key, graphql_query, variables)
        if len(response_data['data']['rss1_articals']) == 0:
            break
        #print(json.dumps(response_data, indent=4))
        s1= []
        ids=[]
        for response in response_data['data']['rss1_articals']:
            article=""
            tags=""
            if (response['rss1_articles_details'][0]['tags']) is None:
                tags = " "
            else:
                tags = ", ".join(response['rss1_articles_details'][0]['tags'])
            article = article + response['title'] + " " +  response['summary'] + " " +  response['rss1_articles_details'][0]['summary'] + tags
            s1.append([['Represent the news article tile and summary for custering and retrieval:  ', article]])
            ids.append(response['id'])
        embeddings = []
        for s in s1:
            list_embeddings = numpy.ravel(model.encode(s)).tolist()
            embeddings.append(list_embeddings)
        for i in range(0,len(ids)):
            articles_vector1_insert_input_loc.append({
                "article_id": ids[i],
                "embedding": str(embeddings[i]),
                }
                )
            rss1_articals_updates_loc.append({
                "where": {"id" : { "_eq": ids[i] }},
                "_set": {"is_vectorized": 1}
                })

        mutation_variables = {
        "objects": articles_vector1_insert_input_loc,
        "updates": rss1_articals_updates_loc,
        }
        out1 = mutation_hasura_graphql(endpoint=endpoint, admin_key=admin_key, mutation_query=mutation_query, mutation_variables=mutation_variables)

# %%
#update_articles_toi()
#update_articles_thehindu()
#update_articles_cnn()
#update_articles_foxnews()

#update_article_detail_toi()
#update_article_detail_cnn(0)
#update_article_detail_foxnews(0)
#summerizer(0)
vectorize(0)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1077}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1077}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1058}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1058}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1059}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1059}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 2}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 2}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 6}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 6}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1060}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1060}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1061}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1061}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1062}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1062}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 21}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 21}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 22}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 22}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 23}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 23}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 12}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 12}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1271}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1271}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1272}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1272}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1279}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1279}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1280}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1280}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1261}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1261}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1262}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1262}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1268}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1268}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1245}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1245}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 24}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 24}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 27}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 27}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 91}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 91}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1246}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1246}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1233}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1233}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1235}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1235}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1229}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1229}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1219}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1219}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1213}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1213}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1214}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1214}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1188}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1188}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1189}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1189}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 456}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 456}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 41}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 41}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 922}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 922}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 923}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 923}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 928}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 928}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 904}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 904}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 906}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 906}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 51}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 51}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 901}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 901}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 902}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 902}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 887}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 887}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 889}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 889}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 869}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 869}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 870}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 870}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 851}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 851}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 853}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 853}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 850}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 850}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 842}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 842}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 844}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 844}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 829}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 829}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 833}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 833}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 841}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 841}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 809}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 809}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 810}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 810}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 790}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 790}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 791}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 791}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 792}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 792}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 793}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 793}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 772}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 772}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 774}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 774}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 778}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 778}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 71}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 71}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 754}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 754}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 756}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 756}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 867}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 867}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 760}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 760}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 742}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 742}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 744}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 744}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 733}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 733}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 729}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 729}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 76}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 76}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 77}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 77}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 78}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 78}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 79}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 79}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 730}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 730}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 712}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 712}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 713}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 713}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 692}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 692}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 696}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 696}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 671}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 671}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 673}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 673}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 677}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 677}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 679}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 679}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 651}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 651}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 90}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 90}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 652}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 652}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 642}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 642}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 643}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 643}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 635}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 635}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 633}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 633}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 634}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 634}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 632}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 632}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 616}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 616}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 618}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 618}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 630}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 630}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 608}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 608}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 525}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 525}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 527}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 527}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 109}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 109}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 105}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 105}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 107}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 107}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 106}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 106}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 104}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 104}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 110}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 110}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 509}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 509}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 510}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 510}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 491}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 491}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 492}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 492}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 472}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 472}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 490}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 490}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 473}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 473}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 474}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 474}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 457}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 457}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 119}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 119}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 118}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 118}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 123}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 123}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 454}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 454}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 459}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 459}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1066}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1066}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 133}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 133}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 127}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 127}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 131}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 131}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 126}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 126}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 125}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 125}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 455}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 455}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 137}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 137}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 140}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 140}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 453}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 453}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 443}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 443}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 442}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 442}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 445}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 445}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 444}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 444}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 447}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 447}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 446}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 446}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 449}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 449}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 448}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 448}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 450}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 450}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 451}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 451}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 452}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 452}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 458}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 458}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 460}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 460}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 461}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 461}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 462}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 462}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 463}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 463}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 464}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 464}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 465}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 465}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 466}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 466}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 467}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 467}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 468}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 468}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 469}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 469}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 470}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 470}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 471}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 471}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 475}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 475}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 476}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 476}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 477}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 477}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 478}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 478}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 479}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 479}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 480}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 480}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 481}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 481}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 482}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 482}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 483}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 483}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 484}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 484}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 485}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 485}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 486}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 486}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 487}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 487}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 488}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 488}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 489}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 489}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 493}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 493}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 494}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 494}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 495}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 495}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 496}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 496}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 497}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 497}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 498}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 498}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 499}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 499}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 500}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 500}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 501}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 501}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 502}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 502}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 503}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 503}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 504}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 504}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 505}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 505}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 506}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 506}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 511}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 511}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 512}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 512}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 513}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 513}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 514}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 514}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 515}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 515}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 516}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 516}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 517}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 517}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 518}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 518}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 519}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 519}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 520}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 520}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 521}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 521}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 522}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 522}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 523}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 523}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 524}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 524}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 507}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 507}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 508}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 508}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 526}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 526}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 528}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 528}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 529}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 529}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 530}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 530}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 531}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 531}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 532}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 532}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 533}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 533}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 534}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 534}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 535}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 535}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 536}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 536}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 537}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 537}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 538}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 538}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 539}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 539}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 614}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 614}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 615}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 615}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 604}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 604}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 605}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 605}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 606}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 606}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 607}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 607}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 609}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 609}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 610}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 610}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 611}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 611}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 612}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 612}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 613}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 613}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 540}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 540}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 541}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 541}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 617}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 617}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 619}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 619}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 620}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 620}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 621}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 621}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 622}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 622}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 623}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 623}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 624}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 624}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 625}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 625}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 626}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 626}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 627}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 627}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 628}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 628}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 629}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 629}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 631}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 631}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 644}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 644}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 645}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 645}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 646}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 646}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 647}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 647}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 648}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 648}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 649}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 649}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 650}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 650}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 636}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 636}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 637}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 637}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 638}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 638}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 639}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 639}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 640}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 640}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 641}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 641}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 653}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 653}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 654}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 654}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 655}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 655}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 656}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 656}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 657}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 657}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 658}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 658}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 659}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 659}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 660}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 660}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 661}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 661}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 662}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 662}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 663}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 663}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 672}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 672}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 674}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 674}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 675}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 675}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 676}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 676}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 664}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 664}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 665}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 665}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 666}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 666}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 667}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 667}]}]}}
# ...
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1169}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1169}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 75}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 75}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 100}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 100}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 101}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 101}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 111}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 111}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 103}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 103}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 108}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 108}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 80}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 80}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 81}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 81}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 82}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 82}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 83}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 83}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 84}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 84}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 85}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 85}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 86}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 86}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 87}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 87}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 88}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 88}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 89}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 89}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1015}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1015}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 999}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 999}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1174}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1174}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1175}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1175}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1177}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1177}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1161}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1161}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1156}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1156}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1159}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1159}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1160}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1160}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1163}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1163}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1164}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1164}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1166}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1166}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1167}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1167}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1152}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1152}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1151}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1151}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1154}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1154}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1155}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1155}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1158}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1158}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1153}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1153}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1138}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1138}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1135}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1135}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1139}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1139}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1133}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1133}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1134}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1134}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1136}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1136}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1137}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1137}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1143}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1143}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1142}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1142}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1144}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1144}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1124}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1124}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1129}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1129}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1126}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1126}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1121}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1121}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1123}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1123}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1128}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1128}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1127}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1127}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1122}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1122}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1116}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1116}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1114}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1114}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1117}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1117}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1109}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1109}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1100}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1100}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1106}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1106}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1103}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1103}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1107}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1107}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1111}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1111}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1104}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1104}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1105}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1105}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1108}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1108}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1102}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1102}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1115}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1115}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1101}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1101}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1094}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1094}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1093}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1093}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1095}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1095}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1092}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1092}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1096}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1096}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1098}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1098}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1091}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1091}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1086}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1086}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1087}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1087}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1089}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1089}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1088}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1088}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1084}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1084}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1081}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1081}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1090}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1090}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1079}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1079}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1080}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1080}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1082}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1082}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1083}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1083}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1056}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1056}]}]}}
# {'data': {'insert_articles_vector1': {'affected_rows': 1, 'returning': [{'article_id': 1055}]}, 'update_rss1_articals_many': [{'affected_rows': 1, 'returning': [{'id': 1055}]}]}}

# %%
mutation_query = """
mutation MyMutation($objects: [articles_vector1_insert_input!] = {}, $updates: [rss1_articals_updates!] = {where: {}}) {
  insert_articles_vector1(objects: $objects, on_conflict: {constraint: articles_vector1_article_id_key}) {
    affected_rows
    returning {
      article_id
    }
  }
  update_rss1_articals_many(updates: $updates) {
    affected_rows
    returning {
      id
    }
  }
}

"""
articles_vector1_insert_input_loc=[]
rss1_articals_updates_loc=[]
for i in range(0,len(ids)-1):
  embeds.append({
    "article_id": ids[i],
    "embedding": str(embeddings[i]),
    }
    )
mutation_variables = {
    "objects": embeds
}
#print({'query': mutation_query, 'variables': mutation_variables})
out1 = mutation_hasura_graphql(endpoint = endpoint, admin_key = admin_key, mutation_query = mutation_query, mutation_variables = mutation_variables)
# Out:
# {'data': {'insert_articles_vector1': {'affected_rows': 11, 'returning': [{'article_id': 12}, {'article_id': 98}, {'article_id': 106}, {'article_id': 666}, {'article_id': 1042}, {'article_id': 1043}, {'article_id': 1044}, {'article_id': 1045}, {'article_id': 1272}, {'article_id': 127}, {'article_id': 608}]}}}

# %%
options = webdriver.EdgeOptions()
options.use_chromium = True
options.add_argument('--enable-immersive-reader')
driver = webdriver.Edge(options=options)

# %%
read_link="https://www.cnn.com/2023/09/02/americas/guatemalan-president-elect-arevalo-alleged-coup-inlt-hnk/index.html"
driver.get(read_link)
get_url = driver.current_url
read_link= "read://"+get_url
driver.get(read_link)

# %%
ARTICLE = ''' New York (CNN)When Liana Barrientos was 23 years old, she got married in Westchester County, New York.
A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband.
Only 18 days after that marriage, she got hitched yet again. Then, Barrientos declared "I do" five more times, sometimes only within two weeks of each other.
In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage.
Barrientos, now 39, is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the
2010 marriage license application, according to court documents.
Prosecutors said the marriages were part of an immigration scam.
On Friday, she pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further.
After leaving court, Barrientos was arrested and charged with theft of service and criminal trespass for allegedly sneaking into the New York subway through an emergency exit, said Detective
Annette Markowski, a police spokeswoman. In total, Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002.
All occurred either in Westchester County, Long Island, New Jersey or the Bronx. She is believed to still be married to four men, and at one time, she was married to eight men at once, prosecutors say.
Prosecutors said the immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages.
Any divorces happened only after such filings were approved. It was unclear whether any of the men will be prosecuted.
The case was referred to the Bronx District Attorney\'s Office by Immigration and Customs Enforcement and the Department of Homeland Security\'s
Investigation Division. Seven of the men are from so-called "red-flagged" countries, including Egypt, Turkey, Georgia, Pakistan and Mali.
Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force.
If convicted, Barrientos faces up to four years in prison.  Her next court appearance is scheduled for May 18.New York (CNN)When Liana Barrientos was 23 years old, she got married in Westchester County, New York.
A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband.
Only 18 days after that marriage, she got hitched yet again. Then, Barrientos declared "I do" five more times, sometimes only within two weeks of each other.
In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage.
Barrientos, now 39, is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the
2010 marriage license application, according to court documents.
Prosecutors said the marriages were part of an immigration scam.
On Friday, she pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further.
After leaving court, Barrientos was arrested and charged with theft of service and criminal trespass for allegedly sneaking into the New York subway through an emergency exit, said Detective
Annette Markowski, a police spokeswoman. In total, Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002.
All occurred either in Westchester County, Long Island, New Jersey or the Bronx. She is believed to still be married to four men, and at one time, she was married to eight men at once, prosecutors say.
Prosecutors said the immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages.
Any divorces happened only after such filings were approved. It was unclear whether any of the men will be prosecuted.
The case was referred to the Bronx District Attorney\'s Office by Immigration and Customs Enforcement and the Department of Homeland Security\'s
Investigation Division. Seven of the men are from so-called "red-flagged" countries, including Egypt, Turkey, Georgia, Pakistan and Mali.
Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force.
If convicted, Barrientos faces up to four years in prison.  Her next court appearance is scheduled for May 18.New York (CNN)When Liana Barrientos was 23 years old, she got married in Westchester County, New York.
A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband.
Only 18 days after that marriage, she got hitched yet again. Then, Barrientos declared "I do" five more times, sometimes only within two weeks of each other.
In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage.
Barrientos, now 39, is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the
2010 marriage license application, according to court documents.
Prosecutors said the marriages were part of an immigration scam.
On Friday, she pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further.
After leaving court, Barrientos was arrested and charged with theft of service and criminal trespass for allegedly sneaking into the New York subway through an emergency exit, said Detective
Annette Markowski, a police spokeswoman. In total, Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002.
All occurred either in Westchester County, Long Island, New Jersey or the Bronx. She is believed to still be married to four men, and at one time, she was married to eight men at once, prosecutors say.
Prosecutors said the immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages.
Any divorces happened only after such filings were approved. It was unclear whether any of the men will be prosecuted.
The case was referred to the Bronx District Attorney\'s Office by Immigration and Customs Enforcement and the Department of Homeland Security\'s
Investigation Division. Seven of the men are from so-called "red-flagged" countries, including Egypt, Turkey, Georgia, Pakistan and Mali.
Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force.
If convicted, Barrientos faces up to four years in prison.  Her next court appearance is scheduled for May 18.New York (CNN)When Liana Barrientos was 23 years old, she got married in Westchester County, New York.
A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband.
Only 18 days after that marriage, she got hitched yet again. Then, Barrientos declared "I do" five more times, sometimes only within two weeks of each other.
In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage.
Barrientos, now 39, is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the
2010 marriage license application, according to court documents.
'''

# %%
import torch

# create a tensor on the CPU
x = torch.randn(10, 10)


# move the tensor to the GPU
x = x.to("cuda")

# check if the tensor is on the GPU
print(x.device)  # should print "cuda:0"
# Out:
# cuda:0

# %%
chunks=[]
max_length = 0
min_length = 0
if len(ARTICLE) < 1000:
    max_length = 150
    min_length = 100
    chunks.append(ARTICLE)
elif len(ARTICLE) < 3000:
    max_length = 300
    min_length = 200
    chunks.append(ARTICLE)
elif len(ARTICLE) < 4000:
    max_length = 400
    min_length = 250
    chunks.append(ARTICLE)
elif len(ARTICLE) < 8000:
    max_length = 200
    min_length = 150
    midpoint = len(ARTICLE) // 2
    chunks.append(ARTICLE[:midpoint])
    chunks.append(ARTICLE[midpoint:])
else:
    ARTICLE=ARTICLE[:8000]
    max_length = 200
    min_length = 150
    midpoint = len(ARTICLE) // 2
    chunks.append(ARTICLE[:midpoint])
    chunks.append(ARTICLE[midpoint:])

summerize=""
for chunk in chunks:
    summerize=summerize + summarizer(chunk, max_length=max_length, min_length=min_length, do_sample=False)[0]['summary_text']+ " "

print(summerize)
# Out:
# ['Liana Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002. In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her "first and only" marriage. She is facing two criminal counts of "offering a false instrument for filing in the first degree," referring to her false statements on the 2010 marriage license application. If convicted, she faces up to four years in prison. Her next court appearance is scheduled for May 18, according to her attorney, Christopher Wright, who declined to comment further. The case was referred to the Bronx District Attorney\'s Office by Immigration and Customs Enforcement and the Department of Homeland Security\'sInvestigation Division.', "Liana Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002. She is believed to still be married to four men, and at one time, she was married to eight men at once. Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force. She pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further. If convicted, she faces up to four years in prison. The case was referred to the Bronx District Attorney's Office by Immigration and Customs Enforcement and the Department of Homeland Security's investigation division. The immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages."]

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device=0)

# %%
sequence_to_classify = """
Scientists identify secret ingredient in Leonardo da Vinci paintings
01b old masters egg yolk painting mona lisa RESTRICTED
Editor’s Note: Sign up for CNN’s Wonder Theory science newsletter. Explore the universe with news on fascinating discoveries, scientific advancements and more.

CNN  — 
“Old Masters” such as Leonardo da Vinci, Sandro Botticelli and Rembrandt may have used proteins, especially egg yolk, in their oil paintings, according to a new study.

Trace quantities of protein residue have long been detected in classic oil paintings, though they were often ascribed to contamination. A new study published Tuesday in the journal Nature Communications found the inclusion was likely intentional — and sheds light on the technical knowledge of the Old Masters, the most skilled European painters of the 16th, 17th, or early 18th century, and the way they prepared their paints.

“There are very few written sources about this and no scientific work has been done before to investigate the subject in such depth,” said study author Ophélie Ranquet of the Institute of Mechanical Process Engineering and Mechanics at the Karlsruhe Institute of Technology in Germany, in a phone interview. “Our results show that even with a very small amount of egg yolk, you can achieve an amazing change of properties in the oil paint, demonstrating how it might have been beneficial for the artists.”

Simply adding some egg yolk to their works, it turns out, could have long-lasting effects that went beyond just aesthetics.

Eggs vs. oil
Compared with the medium formulated by ancient Egyptians called tempera — which combines egg yolk with powdered pigments and water — oil paint creates more intense colors, allows for very smooth color transitions and dries far less quickly, so it can be used for several days after its preparation. However, oil paint, which uses linseed or safflower oil instead of water, also has drawbacks, including being more susceptible to color darkening and damage caused by exposure to light.

Because making paint was an artisanal and experimental process, it is possible that the Old Masters might have added egg yolk, a familiar ingredient, to the newer type of paint, which first showed up in the seventh century in Central Asia before spreading to Northern Europe in the Middle Ages and Italy during the Renaissance. In the study, the researchers recreated the process of paint-making by using four ingredients — egg yolk, distilled water, linseed oil and pigment — to mix two historically popular and significant colors, lead white and ultramarine blue.

“The addition of egg yolk is beneficial because it can tune the properties of these paints in a drastic way,” Ranquet said, “For example by showing aging differently: It takes a longer time for the paint to oxidize, because of the antioxidants contained in the yolk.”

The chemical reactions between the oil, the pigment and the proteins in the yolk directly affect the paint’s behavior and viscosity. “For example, the lead white pigment is quite sensitive to humidity, but if you coat it with a protein layer, it makes it a lot more resistant to it, making the paint quite easy to apply,” Ranquet said.

“On the other hand, if you wanted something stiffer without having to add a lot of pigment, with a bit of egg yolk you can create a high impasto paint,” she added, referring to a painting technique where the paint is laid out in a stroke thick enough that the brushstrokes are still visible. Using less pigment would have been desirable centuries ago, when certain pigments — such as lapis lazuli, which was used to make ultramarine blue — were more expensive than gold, according to Ranquet.

"The Madonna of the Carnation," on display at the Alte Pinakothek in Munich, Germany, is one of Leonardo da Vinci's earliest paintings. Wrinkling of the oil paint is evident on the faces. 
"The Madonna of the Carnation," on display at the Alte Pinakothek in Munich, Germany, is one of Leonardo da Vinci's earliest paintings. Wrinkling of the oil paint is evident on the faces.
DeAgostini/Getty Images
A direct evidence of the effect of egg yolk in oil paint, or lack thereof, can be seen in Leonardo da Vinci’s “Madonna of the Carnation,” one of the paintings observed during the study. Currently on display at the Alte Pinakothek in Munich, Germany, the work shows evident wrinkling on the face of Mary and the child.

“Oil paint starts to dry from the surface down, which is why it wrinkles,” Ranquet said.

One reason for wrinkling may be an insufficient quantity of pigments in the paint, and the study has shown that this effect could be avoided with the addition of egg yolk: “That’s quite amazing because you have the same quantity of pigment in your paint, but the presence of the egg yolk changes everything.”

Because wrinkling occurs within days, it’s likely that Leonardo and other Old Masters might have caught onto this particular effect, as well as additional beneficial properties of egg yolk in oil paint, including resistance to humidity. The “Madonna of Carnation” is one of Leonardo’s earliest paintings, created at a time when he might have been still trying to master the then newly popular medium of oil paint.

New understanding of the classics
Another painting observed during the study was “The Lamentation Over the Dead Christ,” by Botticelli, also on display at the Alte Pinakothek. The work is mostly made with tempera, but oil paint has been used for the background and some secondary elements.

“We knew that some parts of the paintings show brushstrokes that are typical for what we call an oil painting, and yet we detected the presence of proteins,” Ranquet said. “Because it’s a very small quantity and they are difficult to detect, this might be dismissed as contamination: In workshops, artists used many different things, and maybe the eggs were just from the tempera.”

However, because adding egg yolk had such desirable effects on oil paint, the presence of proteins in the work might be an indication of deliberate use instead, the study suggested. Ranquet hopes that these preliminary findings might attract more curiosity toward this understudied topic.

Maria Perla Colombini, a professor of analytical chemistry at the University of Pisa in Italy, who was not involved in the study, agreed. “This exciting paper provides a new scenario for the understanding of old painting techniques,” she said in an email.

“The research group, reporting results from molecular level up to a macroscopic scale, contributes to a new knowledge in the use of egg yolk and oil binders. They are not more looking at simply identifying the materials used by Old Masters but explain how they could produce wonderful and glittering effects by employing and mixing the few available natural materials. They try to discover the secrets of old recipes of which little or nothing is written,” she added.

“This new knowledge contributes not only to a better conservation and preservation of artworks but also to a better comprehension of art history.”


Top image: The “Mona Lisa” by Leonardo Da Vinci
"""
candidate_labels = [ 'Politics' , 'World News' , 'Local News' , 'Business' , 'Technology' , 'Science' , 'Health' , 'Education' , 'Environment' , 'Sports' , 'Entertainment' , 'Culture' , 'Economy' , 'Finance' , 'Crime' , 'Law' , 'Immigration' , 'Climate Change' , 'Weather' , 'International Relations' , 'Government' , 'Elections' , 'Terrorism' , 'Religion' , 'Human Rights' , 'Social Issues' , 'Immigration' , 'Education Reform' , 'Healthcare' , 'COVID-19' , 'Vaccination' , 'Cybersecurity' , 'Artificial Intelligence' , 'Space Exploration' , 'Biotechnology' , 'Mental Health' , 'Travel' , 'Food' , 'Fashion' , 'Lifestyle' , 'Celebrity News' , 'Arts' , 'Music' , 'Film' , 'Television' , 'Books' , 'Gaming' , 'Sports Highlights' , 'Olympic Games' , 'Auto Industry' , 'Real Estate' , 'Stock Market' , 'Trade' , 'Infrastructure' , 'Energy' , 'Sustainability' , 'Wildlife' , 'Conservation' , 'Natural Disasters' , 'Education Policy' , 'Higher Education' , 'Student Life' , 'Parenting' , 'Aging' , 'Disability' , 'LGBTQ+ Rights' , 'Gender Equality' , 'Race Relations' , 'Immigration Policy' , 'Criminal Justice' , 'Courts' , 'Police' , 'Drug Policy' , 'Climate Policy' , 'Renewable Energy' , 'Air Pollution' , 'Oceans' , 'Space Policy' , 'Artificial Intelligence Ethics' , 'Robotics' , 'Social Media' , 'Data Privacy' , 'Hacking' , 'Astronomy' , 'Biology' , 'Psychology' , 'Fitness' , 'Nutrition' , 'TravelDestinations' , 'Culinary Trends' , 'DIY' , 'Celebrity Interviews' , 'Theater' , 'Visual Arts' , 'Pop Culture' , 'Music Festivals' , 'Gaming Industry' , 'Electric Vehicles' , 'Housing Market' , 'Small Business']
classifier(sequence_to_classify, candidate_labels)
# Out:
# {'sequence': '\nScientists identify secret ingredient in Leonardo da Vinci paintings\n01b old masters egg yolk painting mona lisa RESTRICTED\nEditor’s Note: Sign up for CNN’s Wonder Theory science newsletter. Explore the universe with news on fascinating discoveries, scientific advancements and more.\n\nCNN  — \n“Old Masters” such as Leonardo da Vinci, Sandro Botticelli and Rembrandt may have used proteins, especially egg yolk, in their oil paintings, according to a new study.\n\nTrace quantities of protein residue have long been detected in classic oil paintings, though they were often ascribed to contamination. A new study published Tuesday in the journal Nature Communications found the inclusion was likely intentional — and sheds light on the technical knowledge of the Old Masters, the most skilled European painters of the 16th, 17th, or early 18th century, and the way they prepared their paints.\n\n“There are very few written sources about this and no scientific work has been done before to investigate the subject in such depth,” said study author Ophélie Ranquet of the Institute of Mechanical Process Engineering and Mechanics at the Karlsruhe Institute of Technology in Germany, in a phone interview. “Our results show that even with a very small amount of egg yolk, you can achieve an amazing change of properties in the oil paint, demonstrating how it might have been beneficial for the artists.”\n\nSimply adding some egg yolk to their works, it turns out, could have long-lasting effects that went beyond just aesthetics.\n\nEggs vs. oil\nCompared with the medium formulated by ancient Egyptians called tempera — which combines egg yolk with powdered pigments and water — oil paint creates more intense colors, allows for very smooth color transitions and dries far less quickly, so it can be used for several days after its preparation. However, oil paint, which uses linseed or safflower oil instead of water, also has drawbacks, including being more susceptible to color darkening and damage caused by exposure to light.\n\nBecause making paint was an artisanal and experimental process, it is possible that the Old Masters might have added egg yolk, a familiar ingredient, to the newer type of paint, which first showed up in the seventh century in Central Asia before spreading to Northern Europe in the Middle Ages and Italy during the Renaissance. In the study, the researchers recreated the process of paint-making by using four ingredients — egg yolk, distilled water, linseed oil and pigment — to mix two historically popular and significant colors, lead white and ultramarine blue.\n\n“The addition of egg yolk is beneficial because it can tune the properties of these paints in a drastic way,” Ranquet said, “For example by showing aging differently: It takes a longer time for the paint to oxidize, because of the antioxidants contained in the yolk.”\n\nThe chemical reactions between the oil, the pigment and the proteins in the yolk directly affect the paint’s behavior and viscosity. “For example, the lead white pigment is quite sensitive to humidity, but if you coat it with a protein layer, it makes it a lot more resistant to it, making the paint quite easy to apply,” Ranquet said.\n\n“On the other hand, if you wanted something stiffer without having to add a lot of pigment, with a bit of egg yolk you can create a high impasto paint,” she added, referring to a painting technique where the paint is laid out in a stroke thick enough that the brushstrokes are still visible. Using less pigment would have been desirable centuries ago, when certain pigments — such as lapis lazuli, which was used to make ultramarine blue — were more expensive than gold, according to Ranquet.\n\n"The Madonna of the Carnation," on display at the Alte Pinakothek in Munich, Germany, is one of Leonardo da Vinci\'s earliest paintings. Wrinkling of the oil paint is evident on the faces. \n"The Madonna of the Carnation," on display at the Alte Pinakothek in Munich, Ger ...
#  'labels': ['Infrastructure',
#   'Race Relations',
#   'Parenting',
#   'Environment',
#   'Immigration Policy',
#   'Celebrity News',
#   'Natural Disasters',
#   'Aging',
#   'Sustainability',
#   'Science',
#   'Elections',
#   'Hacking',
#   'Lifestyle',
#   'Climate Change',
#   'Immigration',
#   'Immigration',
#   'Climate Policy',
#   'Culture',
#   'Arts',
#   'Government',
#   'Local News',
#   'Fashion',
#   'TravelDestinations',
#   'Mental Health',
#   'Weather',
#   'Visual Arts',
#   'Courts',
#   'Drug Policy',
#   'Renewable Energy',
#   'Psychology',
#   'Air Pollution',
#   'Real Estate',
#   'Entertainment',
#   'Travel',
#   'Criminal Justice',
#   'Music',
#   'Health',
#   'Oceans',
#   'Cybersecurity',
#   'Trade',
#   'Conservation',
#   'Higher Education',
#   'Economy',
#   'Food',
#   'Social Issues',
#   'Education',
#   'Music Festivals',
#   'Pop Culture',
#   'Sports',
#   'Vaccination',
#   'Police',
#   'Energy',
#   'Film',
#   'Crime',
#   'Business',
#   'International Relations',
#   'Finance',
#   'Technology',
#   'Biotechnology',
#   'Gaming Industry',
#   'World News',
#   'Fitness',
#   'Law',
#   'Housing Market',
#   'Gaming',
#   'Education Policy',
#   'Astronomy',
#   'Disability',
#   'Gender Equality',
#   'Electric Vehicles',
#   'Auto Industry',
#   'Culinary Trends',
#   'Small Business',
#   'Celebrity Interviews',
#   'Data Privacy',
#   'Social Media',
#   'Nutrition',
#   'Sports Highlights',
#   'Space Policy',
#   'Human Rights',
#   'Education Reform',
#   'Healthcare',
#   'Theater',
#   'Student Life',
#   'Artificial Intelligence Ethics',
#   'LGBTQ+ Rights',
#   'COVID-19',
#   'Biology',
#   'DIY',
#   'Television',
#   'Stock Market',
#   'Space Exploration',
#   'Politics',
#   'Religion',
#   'Artificial Intelligence',
#   'Wildlife',
#   'Robotics',
#   'Books',
#   'Terrorism',
#   'Olympic Games'],
#  'scores': [0.020620271563529968,
#   0.02055533602833748,
#   0.017592212185263634,
#   0.016919150948524475,
#   0.016125990077853203,
#   0.016118284314870834,
#   0.015916479751467705,
#   0.015595651231706142,
#   0.015550798736512661,
#   0.01501375064253807,
#   0.014481930993497372,
#   0.014171882532536983,
#   0.014057326130568981,
#   0.013848528265953064,
#   0.013623625040054321,
#   0.013623625040054321,
#   0.013404996134340763,
#   0.013217917643487453,
#   0.012996111065149307,
#   0.01287029217928648,
#   0.01286344975233078,
#   0.012800665572285652,
#   0.012724770233035088,
#   0.012587388977408409,
#   0.012267781421542168,
#   0.012170054018497467,
#   0.01215613353997469,
#   0.012012540362775326,
#   0.011851334013044834,
#   0.011831069365143776,
#   0.011731397360563278,
#   0.011454926803708076,
#   0.011197088286280632,
#   0.011133668944239616,
#   0.011042590253055096,
#   0.010822013951838017,
#   0.01076524704694748,
#   0.010681653395295143,
#   0.010590150021016598,
#   0.010497764684259892,
#   0.010452430695295334,
#   0.010379156097769737,
#   0.010319597087800503,
#   0.010300450026988983,
#   0.010269389487802982,
#   0.010220847092568874,
#   0.010116694495081902,
#   0.010060499422252178,
#   0.009914238005876541,
#   0.009821834973990917,
#   0.00973160658031702,
#   0.009487763047218323,
#   0.009372331202030182,
#   0.009222686290740967,
#   0.009049907326698303,
#   0.008979413658380508,
#   0.008938226848840714,
#   0.008869018405675888,
#   0.00880479533225298,
#   0.008739390410482883,
#   0.008690912276506424,
#   0.008604022674262524,
#   0.00857421476393938,
#   0.008532099425792694,
#   0.008386045694351196,
#   0.008372008800506592,
#   0.00836196355521679,
#   0.007954339496791363,
#   0.007876654155552387,
#   0.007832728326320648,
#   0.007760988082736731,
#   0.007668200880289078,
#   0.007430199068039656,
#   0.007276393473148346,
#   0.0072678145952522755,
#   0.007230465766042471,
#   0.007219499908387661,
#   0.007001644931733608,
#   0.006970928981900215,
#   0.006929854862391949,
#   0.006888335105031729,
#   0.0068619889207184315,
#   0.006725491490215063,
#   0.00650226604193449,
#   0.006469366606324911,
#   0.006449126172810793,
#   0.006366319954395294,
#   0.005994728300720453,
#   0.0059402259066700935,
#   0.0059308018535375595,
#   0.005801728926599026,
#   0.005743352230638266,
#   0.005686301272362471,
#   0.005559680983424187,
#   0.004954488016664982,
#   0.004889355972409248,
#   0.0038290091324597597,
#   0.0037014458794146776,
#   0.003665142459794879,
#   0.00356372375972569]}

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import nltk
#nltk.download('punkt')

tokenizer = AutoTokenizer.from_pretrained("fabiochiu/t5-base-tag-generation")
model = AutoModelForSeq2SeqLM.from_pretrained("fabiochiu/t5-base-tag-generation")

text = """
Scientists identify secret ingredient in Leonardo da Vinci paintings
01b old masters egg yolk painting mona lisa RESTRICTED
Editor’s Note: Sign up for CNN’s Wonder Theory science newsletter. Explore the universe with news on fascinating discoveries, scientific advancements and more.

CNN  — 
“Old Masters” such as Leonardo da Vinci, Sandro Botticelli and Rembrandt may have used proteins, especially egg yolk, in their oil paintings, according to a new study.

Trace quantities of protein residue have long been detected in classic oil paintings, though they were often ascribed to contamination. A new study published Tuesday in the journal Nature Communications found the inclusion was likely intentional — and sheds light on the technical knowledge of the Old Masters, the most skilled European painters of the 16th, 17th, or early 18th century, and the way they prepared their paints.

“There are very few written sources about this and no scientific work has been done before to investigate the subject in such depth,” said study author Ophélie Ranquet of the Institute of Mechanical Process Engineering and Mechanics at the Karlsruhe Institute of Technology in Germany, in a phone interview. “Our results show that even with a very small amount of egg yolk, you can achieve an amazing change of properties in the oil paint, demonstrating how it might have been beneficial for the artists.”

Simply adding some egg yolk to their works, it turns out, could have long-lasting effects that went beyond just aesthetics.

Eggs vs. oil
Compared with the medium formulated by ancient Egyptians called tempera — which combines egg yolk with powdered pigments and water — oil paint creates more intense colors, allows for very smooth color transitions and dries far less quickly, so it can be used for several days after its preparation. However, oil paint, which uses linseed or safflower oil instead of water, also has drawbacks, including being more susceptible to color darkening and damage caused by exposure to light.

Because making paint was an artisanal and experimental process, it is possible that the Old Masters might have added egg yolk, a familiar ingredient, to the newer type of paint, which first showed up in the seventh century in Central Asia before spreading to Northern Europe in the Middle Ages and Italy during the Renaissance. In the study, the researchers recreated the process of paint-making by using four ingredients — egg yolk, distilled water, linseed oil and pigment — to mix two historically popular and significant colors, lead white and ultramarine blue.

“The addition of egg yolk is beneficial because it can tune the properties of these paints in a drastic way,” Ranquet said, “For example by showing aging differently: It takes a longer time for the paint to oxidize, because of the antioxidants contained in the yolk.”

The chemical reactions between the oil, the pigment and the proteins in the yolk directly affect the paint’s behavior and viscosity. “For example, the lead white pigment is quite sensitive to humidity, but if you coat it with a protein layer, it makes it a lot more resistant to it, making the paint quite easy to apply,” Ranquet said.

“On the other hand, if you wanted something stiffer without having to add a lot of pigment, with a bit of egg yolk you can create a high impasto paint,” she added, referring to a painting technique where the paint is laid out in a stroke thick enough that the brushstrokes are still visible. Using less pigment would have been desirable centuries ago, when certain pigments — such as lapis lazuli, which was used to make ultramarine blue — were more expensive than gold, according to Ranquet.

"The Madonna of the Carnation," on display at the Alte Pinakothek in Munich, Germany, is one of Leonardo da Vinci's earliest paintings. Wrinkling of the oil paint is evident on the faces. 
"The Madonna of the Carnation," on display at the Alte Pinakothek in Munich, Germany, is one of Leonardo da Vinci's earliest paintings. Wrinkling of the oil paint is evident on the faces.
DeAgostini/Getty Images
A direct evidence of the effect of egg yolk in oil paint, or lack thereof, can be seen in Leonardo da Vinci’s “Madonna of the Carnation,” one of the paintings observed during the study. Currently on display at the Alte Pinakothek in Munich, Germany, the work shows evident wrinkling on the face of Mary and the child.

“Oil paint starts to dry from the surface down, which is why it wrinkles,” Ranquet said.

One reason for wrinkling may be an insufficient quantity of pigments in the paint, and the study has shown that this effect could be avoided with the addition of egg yolk: “That’s quite amazing because you have the same quantity of pigment in your paint, but the presence of the egg yolk changes everything.”

Because wrinkling occurs within days, it’s likely that Leonardo and other Old Masters might have caught onto this particular effect, as well as additional beneficial properties of egg yolk in oil paint, including resistance to humidity. The “Madonna of Carnation” is one of Leonardo’s earliest paintings, created at a time when he might have been still trying to master the then newly popular medium of oil paint.

New understanding of the classics
Another painting observed during the study was “The Lamentation Over the Dead Christ,” by Botticelli, also on display at the Alte Pinakothek. The work is mostly made with tempera, but oil paint has been used for the background and some secondary elements.

“We knew that some parts of the paintings show brushstrokes that are typical for what we call an oil painting, and yet we detected the presence of proteins,” Ranquet said. “Because it’s a very small quantity and they are difficult to detect, this might be dismissed as contamination: In workshops, artists used many different things, and maybe the eggs were just from the tempera.”

However, because adding egg yolk had such desirable effects on oil paint, the presence of proteins in the work might be an indication of deliberate use instead, the study suggested. Ranquet hopes that these preliminary findings might attract more curiosity toward this understudied topic.

Maria Perla Colombini, a professor of analytical chemistry at the University of Pisa in Italy, who was not involved in the study, agreed. “This exciting paper provides a new scenario for the understanding of old painting techniques,” she said in an email.

“The research group, reporting results from molecular level up to a macroscopic scale, contributes to a new knowledge in the use of egg yolk and oil binders. They are not more looking at simply identifying the materials used by Old Masters but explain how they could produce wonderful and glittering effects by employing and mixing the few available natural materials. They try to discover the secrets of old recipes of which little or nothing is written,” she added.

“This new knowledge contributes not only to a better conservation and preservation of artworks but also to a better comprehension of art history.”


Top image: The “Mona Lisa” by Leonardo Da Vinci


"""

inputs = tokenizer([text], max_length=512, truncation=True, return_tensors="pt")
output = model.generate(**inputs, num_beams=8, do_sample=True, min_length=30,
                        max_length=64)
decoded_output = tokenizer.batch_decode(output, skip_special_tokens=True)[0]
tags = list(set(decoded_output.strip().split(", ")))

print(tags)
# ['Programming', 'Code', 'Software Development', 'Programming Languages',
#  'Software', 'Developer', 'Python', 'Software Engineering', 'Science',
#  'Engineering', 'Technology', 'Computer Science', 'Coding', 'Digital', 'Tech',
#  'Python Programming']
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gskch\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Advice', 'Art', 'Painting Tips', 'Creativity', 'Tips And Tricks', 'Tips', 'Painting', 'Artist', 'Creative']
